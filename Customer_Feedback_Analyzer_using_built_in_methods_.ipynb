# %% [markdown]
# <a href="https://colab.research.google.com/github/RajarapuRamya/first-project/blob/feature%2Flogin/Customer_Feedback_Analyzer_using_built_in_methods_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Count total words
def count_words(sentence):
    words = sentence.split()
    return len(words)

# Count total vowels
def count_vowels(sentence):
    vowels = "aeiouAEIOU"
    total = 0

    for ch in sentence:
        if ch in vowels:
            total += 1

    return total

# Find longest word using max()
def longest_word(sentence):
    words = sentence.split()
    return max(words, key=len)

# Reverse each word
def reverse_words(sentence):
    words = sentence.split()

    print("\nReversed Words :")
    for word in words:
        print(word[::-1], end=" ")
    print()

# Display character frequency using count()
def character_frequency(sentence):
    sentence = sentence.lower()
    checked = []

    print("\nCharacter Frequencies :")

    for ch in sentence:
        if ch != " " and ch not in checked:
            print(ch, ":", sentence.count(ch))
            checked.append(ch)

# Main Program
feedback = input("Enter Feedback: ")

print("\nTotal Words :", count_words(feedback))
print("Total Vowels :", count_vowels(feedback))
print("Longest Word :", longest_word(feedback))

reverse_words(feedback)

character_frequency(feedback)
# Out:
# Enter Feedback: Python learning is interesting
#
# Total Words : 4
# Total Vowels : 9
# Longest Word : interesting
#
# Reversed Words :
# nohtyP gninrael si gnitseretni
#
# Character Frequencies :
# p : 1
# y : 1
# t : 3
# h : 1
# o : 1
# n : 5
# l : 1
# e : 3
# a : 1
# r : 2
# i : 4
# g : 2
# s : 2
